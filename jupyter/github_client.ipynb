# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
import os

github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26083',
#   'id': 2507429264,
#   'node_id': 'I_kwDOIPDwls6VdFWQ',
#   'number': 26083,
#   'title': 'ChatGoogleGenerativeAI:  **TypeError** when using @tool decorated methods to perform Tool Calling using Gimini.',
#   'user': {'login': 'AkashBais',
#    'id': 22378405,
#    'node_id': 'MDQ6VXNlcjIyMzc4NDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22378405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AkashBais',
#    'html_url': 'https://github.com/AkashBais',
#    'followers_url': 'https://api.github.com/users/AkashBais/followers',
#    'following_url': 'https://api.github.com/users/AkashBais/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AkashBais/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AkashBais/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AkashBais/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AkashBais/orgs',
#    'repos_url': 'https://api.github.com/users/AkashBais/repos',
#    'events_url': 'https://api.github.com/users/AkashBais/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/AkashBais/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-09-05T10:44:17Z',
#   'updated_at': '2024-09-05T10:46:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n```\r\nfrom langchain_google_genai import ChatGoogleGenerativeAI\r\nmodel_name = "gemini-1.5-flash-001" #"gemini-1.5-pro-latest"\r\nllm = ChatGoogleGenerativeAI(model=model_name,\r\n                              google_api_key=os.getenv(\'GOOGLE_API_KEY_2\'),\r\n                              max_output_tokens = 1024,\r\n                              temperature = 0,\r\n                              verbose=False,\r\n                              )\r\n\r\nllm_with_tools = llm.bind(functions = [search_web, split_documents ] )\r\nresponce = llm_with_tools.invoke("Search for LangChain on DuckDuckGo")\r\n```\r\n\r\n#Tool definitions\r\n\r\n```\r\n@tool(parse_docstring=True)\r\ndef split_documents(\r\n    chunk_size: int,\r\n    knowledge_base: Annotated[Union[List[LangchainDocument], LangchainDocument], InjectedToolArg],\r\n    chunk_overlap: Optional[int] = None,\r\n    tokenizer_name: Annotated[Optional[str], InjectedToolArg] = config.EMBEDDING_MODEL_NAME\r\n) -> List[LangchainDocument]:\r\n\r\n    """\r\n    This method is an implimentation of Text splitter that uses HuggingFace tokenizer to count length.\r\n    This method is to be called for chuncking a Langchain Document/List of Langchain Documents.\r\n    Returns a list of chuncked LangChain Document(s)\r\n  \r\n    Args:\r\n      chunk_size: "Size of Chunks to be created, in number of tokens.Depends on the Context window length of the Embedding model"\r\n      knowledge_base: "List of Langchain Document(s) to process. To be passed at run time\r\n      chunk_overlap: "Size of overlap between Chunks, in number of tokens"\r\n      tokenizer_name: "Name of the tokanizer model to be used for tokanization before chunking the Langchain Document(s) in knowledge_base"\r\n    """\r\n   # Tool Code\r\n\r\n@tool(parse_docstring=True)\r\ndef search_web(\r\n    query:str,\r\n    engine:Optional[str]="Google",\r\n    num_results:Optional[int]=5,\r\n    truncate_threshold:Optional[int]=None,\r\n) -> List[LangchainDocument]:\r\n\r\n    """\r\n    Performs web search for the passed query using the desired search engine\'s API.\r\n    This function will then use web scraping to get page content and return them as a list of LangChain documents.\r\n  \r\n    Args:\r\n      query:"Query to perform Web search for"\r\n      engine: "The search engine to use for the web search"\r\n      num_results: "The number of search results to return from web search"\r\n      truncate_threshold: "Threshold in number of characters to truncate each web pages\' content"\r\n    """\r\n  \r\n   # Tool Code\r\n```\n\n### Error Message and Stack Trace (if applicable)\n\n```\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n[<ipython-input-12-af095bbdae0b>](https://localhost:8080/#) in <cell line: 1>()\r\n----> 1 responce = llm_with_tools.invoke("Search for LangChain on DuckDuckGo")\r\n\r\n10 frames\r\n[/usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py](https://localhost:8080/#) in invoke(self, input, config, **kwargs)\r\n   5090         **kwargs: Optional[Any],\r\n   5091     ) -> Output:\r\n-> 5092         return self.bound.invoke(\r\n   5093             input,\r\n   5094             self._merge_configs(config),\r\n\r\n[/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py](https://localhost:8080/#) in invoke(self, input, config, stop, **kwargs)\r\n    275         return cast(\r\n    276         ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26083/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26081',
#   'id': 2507198114,
#   'node_id': 'I_kwDOIPDwls6VcM6i',
#   'number': 26081,
#   'title': 'DOC: <Issue related to /v0.2/docs/tutorials/chatbot/> How to check LangSmith trace ?',
#   'user': {'login': 'qiulang',
#    'id': 516243,
#    'node_id': 'MDQ6VXNlcjUxNjI0Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/516243?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qiulang',
#    'html_url': 'https://github.com/qiulang',
#    'followers_url': 'https://api.github.com/users/qiulang/followers',
#    'following_url': 'https://api.github.com/users/qiulang/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/qiulang/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/qiulang/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/qiulang/subscriptions',
#    'organizations_url': 'https://api.github.com/users/qiulang/orgs',
#    'repos_url': 'https://api.github.com/users/qiulang/repos',
#    'events_url': 'https://api.github.com/users/qiulang/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/qiulang/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-09-05T08:59:17Z',
#   'updated_at': '2024-09-05T09:01:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### URL\r\n\r\nhttps://python.langchain.com/v0.2/docs/tutorials/chatbot/\r\n\r\n### Checklist\r\n\r\n- [X] I added a very descriptive title to this issue.\r\n- [X] I included a link to the documentation page I am referring to (if applicable).\r\n\r\n### Issue with current documentation:\r\n\r\nThe document says "If you take a look at LangSmith, you can see exactly what is happening under the hood in the LangSmith trace"\r\n\r\nBut when I check trace I don\'t understand what trace can tell me exactly and what is happening under the hood. I don\'t know what the trace can tell me more than what the document already mention.\r\n\r\nPlease add a section to explain how to interpret the LangSmith track.\r\n\r\nFor example, did this trace tell me more than what is said on the document ? I can\'t tell now.\r\n\r\n<img width="762" alt="LanfSmith trace" src="https://github.com/user-attachments/assets/f7e2b1a4-ff72-4d3e-905d-fd98b05b1de9">\r\n\r\n\r\n\r\n### Idea or request for content:\r\n\r\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26081/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26080',
#   'id': 2507118207,
#   'node_id': 'PR_kwDOIPDwls56fXXX',
#   'number': 26080,
#   'title': 'Add PiecesOS LLM integration',
#   'user': {'login': 'sambhavnoobcoder',
#    'id': 94298612,
#    'node_id': 'U_kgDOBZ7h9A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94298612?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sambhavnoobcoder',
#    'html_url': 'https://github.com/sambhavnoobcoder',
#    'followers_url': 'https://api.github.com/users/sambhavnoobcoder/followers',
#    'following_url': 'https://api.github.com/users/sambhavnoobcoder/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sambhavnoobcoder/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sambhavnoobcoder/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sambhavnoobcoder/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sambhavnoobcoder/orgs',
#    'repos_url': 'https://api.github.com/users/sambhavnoobcoder/repos',
#    'events_url': 'https://api.github.com/users/sambhavnoobcoder/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sambhavnoobcoder/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-05T08:23:05Z',
#   'updated_at': '2024-09-05T10:58:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26080',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26080.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26080.patch',
#    'merged_at': None},
#   'body': '## Description:\r\nThis PR introduces the PiecesOSLLM class, which integrates the Pieces OS language model into the LangChain framework. The class includes methods for model interaction, streaming, and model configuration. \r\n\r\n## Key Features:\r\n### PiecesOSLLM Class:\r\n- Inherits from BaseLLM and provides an interface for interacting with the Pieces OS language model.\r\n### Model Configuration:\r\n- set_model: Allows setting the model to be used from the list of supported models. Includes error handling for unsupported models.\r\n- get_supported_models: Retrieves the list of models supported by Pieces OS using ModelFoundationEnum.\r\n### LLM Interaction:\r\n- _call: Synchronously calls the Pieces OS model with a given prompt and returns the first answer from the response.\r\n- _generate: Generates responses for a list of prompts and returns them as LLMResult.\r\n### Streaming:\r\n- stream: Streams responses from the Pieces OS model and yields each response as a GenerationChunk. Includes error handling to yield an error message in case of issues.\r\n### Identifying Parameters:\r\n- _llm_type: Returns the LLM type as "pieces_os".\r\n- _identifying_params: Retrieves and returns the identifying parameters, specifically the selected model.\r\n\r\n## Testing:\r\nThis was the code snippet used to test the functionality:\r\n\r\n```python\r\n# Initialize the LLM\r\nllm = PiecesOSLLM(client=PiecesClient())\r\n\r\n# Print supported models\r\nprint("Supported models:", llm.get_supported_models())\r\n\r\n# Set a specific model\r\nllm.set_model("GPT-4 Chat Model")\r\n\r\n# Use the model for generation\r\nprompt = "Explain a bit about OOPS concepts in computer programming"\r\nfor chunk in llm.stream(prompt):\r\n    print(chunk.text, end="")\r\n```\r\n\r\n## Checklist:\r\n- [x] Implement PiecesOSLLM class.\r\n- [x] Add model selection with set_model.\r\n- [x] Add method to retrieve supported models (get_supported_models).\r\n- [x] Implement synchronous LLM interaction (_call, _generate).\r\n- [x] Implement streaming functionality (stream).\r\n- [x] Add error handling for API interactions.\r\n\r\n## Screenshot\r\n\r\nHere\'s a screenshot of the code giving output in the testing as expected : \r\n\r\n<img width="1133" alt="Screenshot 2024-09-03 at 11 22 40\u202fPM" src="https://github.com/user-attachments/assets/c9fa8a0a-3238-4430-b124-4d3a0d9b6be7">\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26077',
#   'id': 2506726029,
#   'node_id': 'I_kwDOIPDwls6VaZqN',
#   'number': 26077,
#   'title': 'Neo4j example cannot use APOC procedures.',
#   'user': {'login': 'dwschulze',
#    'id': 1429258,
#    'node_id': 'MDQ6VXNlcjE0MjkyNTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1429258?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dwschulze',
#    'html_url': 'https://github.com/dwschulze',
#    'followers_url': 'https://api.github.com/users/dwschulze/followers',
#    'following_url': 'https://api.github.com/users/dwschulze/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dwschulze/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dwschulze/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dwschulze/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dwschulze/orgs',
#    'repos_url': 'https://api.github.com/users/dwschulze/repos',
#    'events_url': 'https://api.github.com/users/dwschulze/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dwschulze/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-09-05T04:12:07Z',
#   'updated_at': '2024-09-05T04:14:34Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### URL\n\nhttps://python.langchain.com/v0.2/docs/tutorials/graph/\n\n### Checklist\n\n- [X] I added a very descriptive title to this issue.\n- [X] I included a link to the documentation page I am referring to (if applicable).\n\n### Issue with current documentation:\n\nThe current docs here (and on the neo4j installation page) are missing several steps:\r\n\r\nInstall apoc*.jar file\r\nUpdate neo4j.conf file\r\n\r\nEven after installing the .jar file with appropriate permissions and updating the .conf file and restarting neo4j I get this error:\r\n\r\n/home/dean/anaconda3/envs/graph/bin/python /home/dean/src/ai/langchain/examples/langchain-tutorials/graph/load_neo4j.py \r\nTraceback (most recent call last):\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py", line 393, in __init__\r\n    self.refresh_schema()\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py", line 444, in refresh_schema\r\n    for el in self.query(\r\n              ^^^^^^^^^^^\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py", line 428, in query\r\n    data = session.run(Query(text=query, timeout=self.timeout), params)\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/work/session.py", line 314, in run\r\n    self._auto_result._run(\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/work/result.py", line 221, in _run\r\n    self._attach()\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/work/result.py", line 409, in _attach\r\n    self._connection.fetch_message()\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/io/_common.py", line 178, in inner\r\n    func(*args, **kwargs)\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py", line 860, in fetch_message\r\n    res = self._process_message(tag, fields)\r\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/io/_bolt5.py", line 370, in _process_message\r\n    response.on_failure(summary_metadata or {})\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/neo4j/_sync/io/_common.py", line 245, in on_failure\r\n    raise Neo4jError.hydrate(**metadata)\r\nneo4j.exceptions.ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `apoc.meta.data` registered for this database instance. Please ensure you\'ve spelled the procedure name correctly and that the procedure is properly deployed.}\r\n\r\nDuring handling of the above exception, another exception occurred:\r\n\r\nTraceback (most recent call last):\r\n  File "/home/dean/src/ai/langchain/examples/langchain-tutorials/graph/load_neo4j.py", line 9, in <module>\r\n    graph = Neo4jGraph()\r\n            ^^^^^^^^^^^^\r\n  File "/home/dean/anaconda3/envs/graph/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py", line 396, in __init__\r\n    raise ValueError(\r\nValueError: Could not use APOC procedures. Please ensure the APOC plugin is installed in Neo4j and that \'apoc.meta.data()\' is allowed in Neo4j configuration \r\n\r\nProcess finished with exit code 1\r\n\n\n### Idea or request for content:\n\nNeed complete setup procedures to use APOC procedures.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26077/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26075',
#   'id': 2506546036,
#   'node_id': 'PR_kwDOIPDwls56dcMs',
#   'number': 26075,
#   'title': 'huggingface: fix _convert_TGI_message_to_LC_message issue, which will replace all …',
#   'user': {'login': 'sywangyi',
#    'id': 36058628,
#    'node_id': 'MDQ6VXNlcjM2MDU4NjI4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36058628?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sywangyi',
#    'html_url': 'https://github.com/sywangyi',
#    'followers_url': 'https://api.github.com/users/sywangyi/followers',
#    'following_url': 'https://api.github.com/users/sywangyi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sywangyi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sywangyi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sywangyi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sywangyi/orgs',
#    'repos_url': 'https://api.github.com/users/sywangyi/repos',
#    'events_url': 'https://api.github.com/users/sywangyi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sywangyi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-09-05T00:48:35Z',
#   'updated_at': '2024-09-05T00:51:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26075',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26075.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26075.patch',
#    'merged_at': None},
#   'body': '…\' in content like It\'s to It"s and cause json parser fail\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n    - **Twitter handle:** if your PR gets announced, and you\'d like a mention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26074',
#   'id': 2506534404,
#   'node_id': 'PR_kwDOIPDwls56dZqm',
#   'number': 26074,
#   'title': "Update FeatureTables.js to reflect Cohere's support for JSON mode",
#   'user': {'login': 'ryanchase-0to1',
#    'id': 167824500,
#    'node_id': 'U_kgDOCgDMdA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167824500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryanchase-0to1',
#    'html_url': 'https://github.com/ryanchase-0to1',
#    'followers_url': 'https://api.github.com/users/ryanchase-0to1/followers',
#    'following_url': 'https://api.github.com/users/ryanchase-0to1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ryanchase-0to1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ryanchase-0to1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ryanchase-0to1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ryanchase-0to1/orgs',
#    'repos_url': 'https://api.github.com/users/ryanchase-0to1/repos',
#    'events_url': 'https://api.github.com/users/ryanchase-0to1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ryanchase-0to1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-05T00:35:39Z',
#   'updated_at': '2024-09-05T00:48:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26074',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26074',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26074.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26074.patch',
#    'merged_at': None},
#   'body': '- [ ] **PR title**: "docs: update FeatureTables.js to reflect Cohere\'s support for JSON mode"\r\n- [ ] **PR message**: Update FeatureTables.js to reflect Cohere\'s support for JSON mode\r\n\r\n- [ ] **Description:** updated Cohere\'s record in the Featured Providers table [1].  Set "json_mode" to true as Cohere\'s models support JSON mode [2].\r\n\r\n[1] source table: https://python.langchain.com/v0.2/docs/integrations/chat/#featured-providers\r\n\r\n[2] Cohere\'s api reference showing support for JSON mode  i.e. response_format={ "type": "json_object" }\r\nhttps://docs.cohere.com/docs/structured-outputs-json\r\n\r\n- **Twitter handle:** @ryanchase1',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26073',
#   'id': 2506472366,
#   'node_id': 'PR_kwDOIPDwls56dMOy',
#   'number': 26073,
#   'title': '[Tests] Clear cache for env-var checks',
#   'user': {'login': 'hinthornw',
#    'id': 13333726,
#    'node_id': 'MDQ6VXNlcjEzMzMzNzI2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13333726?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hinthornw',
#    'html_url': 'https://github.com/hinthornw',
#    'followers_url': 'https://api.github.com/users/hinthornw/followers',
#    'following_url': 'https://api.github.com/users/hinthornw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hinthornw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hinthornw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hinthornw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hinthornw/orgs',
#    'repos_url': 'https://api.github.com/users/hinthornw/repos',
#    'events_url': 'https://api.github.com/users/hinthornw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hinthornw/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5454193895,
#     'node_id': 'LA_kwDOIPDwls8AAAABRRhk5w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/lgtm',
#     'name': 'lgtm',
#     'color': '0E8A16',
#     'default': False,
#     'description': 'PR looks good. Use to confirm that a PR is ready for merging.'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-04T23:27:37Z',
#   'updated_at': '2024-09-05T00:00:10Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26073',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26073',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26073.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26073.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26073/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26066',
#   'id': 2506270868,
#   'node_id': 'PR_kwDOIPDwls56cfx-',
#   'number': 26066,
#   'title': 'templates: Aerospike Vector Store RAG template',
#   'user': {'login': 'dwelch-spike',
#    'id': 53876192,
#    'node_id': 'MDQ6VXNlcjUzODc2MTky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53876192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dwelch-spike',
#    'html_url': 'https://github.com/dwelch-spike',
#    'followers_url': 'https://api.github.com/users/dwelch-spike/followers',
#    'following_url': 'https://api.github.com/users/dwelch-spike/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dwelch-spike/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dwelch-spike/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dwelch-spike/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dwelch-spike/orgs',
#    'repos_url': 'https://api.github.com/users/dwelch-spike/repos',
#    'events_url': 'https://api.github.com/users/dwelch-spike/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dwelch-spike/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-04T20:54:02Z',
#   'updated_at': '2024-09-04T20:56:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26066',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26066',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26066.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26066.patch',
#    'merged_at': None},
#   'body': "Thank you for contributing to LangChain!\r\n\r\n\r\n  - **Description:** Adds a RAG template using Aerospike Vector Search as a vector store, an OpenAI LLM, and HuggingFace embeddings.\r\n  - **Issue:** NA\r\n  - **Dependencies:** Dependencies for running the template are specified in the pyproject.toml. No new dependencies needed for the langchain project.\r\n\r\n\r\n- [x ] **Add tests and docs**: Added a notebook for integrating the template with a langchain app. No tests added.\r\n\r\n\r\n- [x ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you've modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26066/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26065',
#   'id': 2506245450,
#   'node_id': 'PR_kwDOIPDwls56cZ93',
#   'number': 26065,
#   'title': 'support epsilla cloud vector database in langchain',
#   'user': {'login': 'eric-epsilla',
#    'id': 132873174,
#    'node_id': 'U_kgDOB-t71g',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/132873174?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eric-epsilla',
#    'html_url': 'https://github.com/eric-epsilla',
#    'followers_url': 'https://api.github.com/users/eric-epsilla/followers',
#    'following_url': 'https://api.github.com/users/eric-epsilla/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eric-epsilla/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eric-epsilla/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eric-epsilla/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eric-epsilla/orgs',
#    'repos_url': 'https://api.github.com/users/eric-epsilla/repos',
#    'events_url': 'https://api.github.com/users/eric-epsilla/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eric-epsilla/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-04T20:45:15Z',
#   'updated_at': '2024-09-05T00:16:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26065',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26065',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26065.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26065.patch',
#    'merged_at': None},
#   'body': 'Description\r\n\r\n- support epsilla cloud in langchain\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26065/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26060',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26060/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26060/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26060/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26060',
#   'id': 2506178115,
#   'node_id': 'PR_kwDOIPDwls56cK_c',
#   'number': 26060,
#   'title': 'core: fix "template" not allowed as prompt param',
#   'user': {'login': 'ikbenale',
#    'id': 2125699,
#    'node_id': 'MDQ6VXNlcjIxMjU2OTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2125699?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ikbenale',
#    'html_url': 'https://github.com/ikbenale',
#    'followers_url': 'https://api.github.com/users/ikbenale/followers',
#    'following_url': 'https://api.github.com/users/ikbenale/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ikbenale/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ikbenale/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ikbenale/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ikbenale/orgs',
#    'repos_url': 'https://api.github.com/users/ikbenale/repos',
#    'events_url': 'https://api.github.com/users/ikbenale/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ikbenale/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
# ...
#    'repos_url': 'https://api.github.com/users/kk9393/repos',
#    'events_url': 'https://api.github.com/users/kk9393/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kk9393/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5454193895,
#     'node_id': 'LA_kwDOIPDwls8AAAABRRhk5w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/lgtm',
#     'name': 'lgtm',
#     'color': '0E8A16',
#     'default': False,
#     'description': 'PR looks good. Use to confirm that a PR is ready for merging.'},
#    {'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-04T08:23:21Z',
#   'updated_at': '2024-09-04T13:47:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26020',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/26020',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/26020.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/26020.patch',
#    'merged_at': None},
#   'body': 'In the previous implementation, `skip_count` was counting all the documents in the collection. Instead, we want to filter the documents by `session_id` and calculate `skip_count` by subtracting `history_size` from the filtered count.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26020/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26020/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26019',
#   'id': 2504598215,
#   'node_id': 'I_kwDOIPDwls6VSSLH',
#   'number': 26019,
#   'title': 'Prevent Infinite Tool Call Loop in Customer Support Agent (LangGraph)',
#   'user': {'login': 'AtmehEsraa',
#    'id': 153764152,
#    'node_id': 'U_kgDOCSpBOA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153764152?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AtmehEsraa',
#    'html_url': 'https://github.com/AtmehEsraa',
#    'followers_url': 'https://api.github.com/users/AtmehEsraa/followers',
#    'following_url': 'https://api.github.com/users/AtmehEsraa/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AtmehEsraa/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AtmehEsraa/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AtmehEsraa/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AtmehEsraa/orgs',
#    'repos_url': 'https://api.github.com/users/AtmehEsraa/repos',
#    'events_url': 'https://api.github.com/users/AtmehEsraa/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/AtmehEsraa/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-09-04T08:03:13Z',
#   'updated_at': '2024-09-04T08:05:35Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn't find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n[customer_support_llama3.zip](https://github.com/user-attachments/files/16862758/customer_support_llama3.zip)\r\n\n\n### Error Message and Stack Trace (if applicable)\n\n_No response_\n\n### Description\n\nThe customer support agent implemented using LangGraph encounters an issue where it enters an infinite loop when calling tools for information retrieval, such as flight status. The agent repeatedly calls the same tool without processing the output or providing a response to the user. This issue needs to be resolved to improve the efficiency and usability of the agent.\r\n\r\n\n\n### System Info\n\ninstall langchain-core==0.2.9 langchain-community==0.2.5 langchain-experimental==0.0.61 \\\r\n    langgraph==0.0.69 \r\n",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26019/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26018',
#   'id': 2504547513,
#   'node_id': 'I_kwDOIPDwls6VSFy5',
#   'number': 26018,
#   'title': 'langchain-airbyte: Please bump Python 3.12 version limit',
#   'user': {'login': 'glaubitz',
#    'id': 1647645,
#    'node_id': 'MDQ6VXNlcjE2NDc2NDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1647645?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/glaubitz',
#    'html_url': 'https://github.com/glaubitz',
#    'followers_url': 'https://api.github.com/users/glaubitz/followers',
#    'following_url': 'https://api.github.com/users/glaubitz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/glaubitz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/glaubitz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/glaubitz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/glaubitz/orgs',
#    'repos_url': 'https://api.github.com/users/glaubitz/repos',
#    'events_url': 'https://api.github.com/users/glaubitz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/glaubitz/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-09-04T07:37:51Z',
#   'updated_at': '2024-09-04T07:37:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn't find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\nIt's not possible to build the `langchain` package on Debian unstable or openSUSE Tumbleweed as the system version of Python 3.12 is 3.12.5.\n\n### Error Message and Stack Trace (if applicable)\n\n```\r\nERROR: Package 'langchain-airbyte' requires a different Python: 3.12.5 not in '<3.12.4,>=3.9'\r\n```\n\n### Description\n\nI'm trying to package `langchain` for openSUSE Tumbleweed.\n\n### System Info\n\nPython 3.12.5 on openSUSE Tumbleweed",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26018/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/26017',
#   'id': 2504477196,
#   'node_id': 'I_kwDOIPDwls6VR0oM',
#   'number': 26017,
#   'title': 'Supabase vectorstore uses different schema from docs',
#   'user': {'login': 'tristanbob',
#    'id': 8879811,
#    'node_id': 'MDQ6VXNlcjg4Nzk4MTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8879811?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tristanbob',
#    'html_url': 'https://github.com/tristanbob',
#    'followers_url': 'https://api.github.com/users/tristanbob/followers',
#    'following_url': 'https://api.github.com/users/tristanbob/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tristanbob/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tristanbob/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tristanbob/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tristanbob/orgs',
#    'repos_url': 'https://api.github.com/users/tristanbob/repos',
#    'events_url': 'https://api.github.com/users/tristanbob/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tristanbob/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-09-04T07:02:18Z',
#   'updated_at': '2024-09-04T23:28:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\r\n\r\n- [X] I added a very descriptive title to this issue.\r\n- [X] I searched the LangChain documentation with the integrated search.\r\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\r\n- [X] I am sure that this is a bug in LangChain rather than my code.\r\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\r\n\r\n### Example Code\r\n\r\nN/A\r\n\r\n### Error Message and Stack Trace (if applicable)\r\n\r\nError Building Component\r\nError building Component Supabase: {\'code\': \'22P02\', \'details\': None, \'hint\': None, \'message\': \'invalid input syntax for type bigint: "e6ab58f8-c30b-44a7-b1d7-708a9650e6e7"\'}\r\n\r\n### Description\r\n\r\nThe Langchain Supabase vectorstore is expecting a `uuid` primary key for documents:\r\n\r\nhttps://github.com/langchain-ai/langchain/blob/master/libs/community/langchain_community/vectorstores/supabase.py\r\n\r\nHowever, both the Langchain and Supabase docs use a `bigserial` for the data type.\r\n\r\nLangchain:\r\nhttps://js.langchain.com/v0.2/docs/integrations/vectorstores/supabase/\r\n\r\nSupabase:\r\nhttps://supabase.com/docs/guides/ai/langchain?queryGroups=database-method&database-method=sql\r\n\r\nWhen I changed my schema to use the `uuid`, I was able to use the Supabase vectorstore (via Langflow).\r\n\r\nThe long-term fix is to change Langchain from `uuid` to `bigserial`.\r\n\r\n### System Info\r\n\r\nN/A',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26017/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080',
#   'id': 2055042519,
#   'node_id': 'PR_kwDOIPDwls56fXXX',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26080',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/26080.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/26080.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080',
#   'number': 26080,
#   'state': 'open',
#   'locked': False,
#   'title': 'Add PiecesOS LLM integration',
#   'user': {'login': 'sambhavnoobcoder',
#    'id': 94298612,
#    'node_id': 'U_kgDOBZ7h9A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94298612?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sambhavnoobcoder',
#    'html_url': 'https://github.com/sambhavnoobcoder',
#    'followers_url': 'https://api.github.com/users/sambhavnoobcoder/followers',
#    'following_url': 'https://api.github.com/users/sambhavnoobcoder/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sambhavnoobcoder/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sambhavnoobcoder/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sambhavnoobcoder/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sambhavnoobcoder/orgs',
#    'repos_url': 'https://api.github.com/users/sambhavnoobcoder/repos',
#    'events_url': 'https://api.github.com/users/sambhavnoobcoder/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sambhavnoobcoder/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '## Description:\r\nThis PR introduces the PiecesOSLLM class, which integrates the Pieces OS language model into the LangChain framework. The class includes methods for model interaction, streaming, and model configuration. \r\n\r\n## Key Features:\r\n### PiecesOSLLM Class:\r\n- Inherits from BaseLLM and provides an interface for interacting with the Pieces OS language model.\r\n### Model Configuration:\r\n- set_model: Allows setting the model to be used from the list of supported models. Includes error handling for unsupported models.\r\n- get_supported_models: Retrieves the list of models supported by Pieces OS using ModelFoundationEnum.\r\n### LLM Interaction:\r\n- _call: Synchronously calls the Pieces OS model with a given prompt and returns the first answer from the response.\r\n- _generate: Generates responses for a list of prompts and returns them as LLMResult.\r\n### Streaming:\r\n- stream: Streams responses from the Pieces OS model and yields each response as a GenerationChunk. Includes error handling to yield an error message in case of issues.\r\n### Identifying Parameters:\r\n- _llm_type: Returns the LLM type as "pieces_os".\r\n- _identifying_params: Retrieves and returns the identifying parameters, specifically the selected model.\r\n\r\n## Testing:\r\nThis was the code snippet used to test the functionality:\r\n\r\n```python\r\n# Initialize the LLM\r\nllm = PiecesOSLLM(client=PiecesClient())\r\n\r\n# Print supported models\r\nprint("Supported models:", llm.get_supported_models())\r\n\r\n# Set a specific model\r\nllm.set_model("GPT-4 Chat Model")\r\n\r\n# Use the model for generation\r\nprompt = "Explain a bit about OOPS concepts in computer programming"\r\nfor chunk in llm.stream(prompt):\r\n    print(chunk.text, end="")\r\n```\r\n\r\n## Checklist:\r\n- [x] Implement PiecesOSLLM class.\r\n- [x] Add model selection with set_model.\r\n- [x] Add method to retrieve supported models (get_supported_models).\r\n- [x] Implement synchronous LLM interaction (_call, _generate).\r\n- [x] Implement streaming functionality (stream).\r\n- [x] Add error handling for API interactions.\r\n\r\n## Screenshot\r\n\r\nHere\'s a screenshot of the code giving output in the testing as expected : \r\n\r\n<img width="1133" alt="Screenshot 2024-09-03 at 11 22 40\u202fPM" src="https://github.com/user-attachments/assets/c9fa8a0a-3238-4430-b124-4d3a0d9b6be7">\r\n\r\n',
#   'created_at': '2024-09-05T08:23:05Z',
#   'updated_at': '2024-09-05T11:02:05Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '93a0e554830a7c8b1f4e7006b8847cde23fef0f2',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': True,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/d3c5a6481cd4f10af312f8c7118c824d614619c3',
#   'head': {'label': 'sambhavnoobcoder:add-pieces-llm',
#    'ref': 'add-pieces-llm',
#    'sha': 'd3c5a6481cd4f10af312f8c7118c824d614619c3',
#    'user': {'login': 'sambhavnoobcoder',
#     'id': 94298612,
#     'node_id': 'U_kgDOBZ7h9A',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/94298612?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sambhavnoobcoder',
#     'html_url': 'https://github.com/sambhavnoobcoder',
#     'followers_url': 'https://api.github.com/users/sambhavnoobcoder/followers',
#     'following_url': 'https://api.github.com/users/sambhavnoobcoder/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sambhavnoobcoder/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sambhavnoobcoder/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sambhavnoobcoder/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sambhavnoobcoder/orgs',
#     'repos_url': 'https://api.github.com/users/sambhavnoobcoder/repos',
#     'events_url': 'https://api.github.com/users/sambhavnoobcoder/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sambhavnoobcoder/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 846091342,
#     'node_id': 'R_kgDOMm5UTg',
#     'name': 'Langchain-Pieces-Integration',
#     'full_name': 'sambhavnoobcoder/Langchain-Pieces-Integration',
#     'private': False,
#     'owner': {'login': 'sambhavnoobcoder',
#      'id': 94298612,
#      'node_id': 'U_kgDOBZ7h9A',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/94298612?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sambhavnoobcoder',
#      'html_url': 'https://github.com/sambhavnoobcoder',
#      'followers_url': 'https://api.github.com/users/sambhavnoobcoder/followers',
#      'following_url': 'https://api.github.com/users/sambhavnoobcoder/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sambhavnoobcoder/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sambhavnoobcoder/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sambhavnoobcoder/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sambhavnoobcoder/orgs',
#      'repos_url': 'https://api.github.com/users/sambhavnoobcoder/repos',
#      'events_url': 'https://api.github.com/users/sambhavnoobcoder/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sambhavnoobcoder/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/sambhavnoobcoder/Langchain-Pieces-Integration',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration',
#     'forks_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/forks',
#     'keys_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/teams',
#     'hooks_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/hooks',
#     'issue_events_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/events',
#     'assignees_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/tags',
#     'blobs_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/languages',
#     'stargazers_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/stargazers',
#     'contributors_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/contributors',
#     'subscribers_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/subscribers',
#     'subscription_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/subscription',
#     'commits_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/merges',
#     'archive_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/downloads',
#     'issues_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/sambhavnoobcoder/Langchain-Pieces-Integration/deployments',
#     'created_at': '2024-08-22T14:10:16Z',
#     'updated_at': '2024-08-22T14:10:16Z',
#     'pushed_at': '2024-09-05T11:01:58Z',
#     'git_url': 'git://github.com/sambhavnoobcoder/Langchain-Pieces-Integration.git',
#     'ssh_url': 'git@github.com:sambhavnoobcoder/Langchain-Pieces-Integration.git',
#     'clone_url': 'https://github.com/sambhavnoobcoder/Langchain-Pieces-Integration.git',
#     'svn_url': 'https://github.com/sambhavnoobcoder/Langchain-Pieces-Integration',
#     'homepage': 'https://python.langchain.com',
#     'size': 237451,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'de97d5064437c98f34dae0b0afa3b61162790726',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-09-05T11:01:07Z',
#     'pushed_at': '2024-09-05T04:23:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 293227,
#     'stargazers_count': 91964,
#     'watchers_count': 91964,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14627,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 801,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14627,
#     'open_issues': 801,
#     'watchers': 91964,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/26080'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/26080/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26080/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/d3c5a6481cd4f10af312f8c7118c824d614619c3'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075',
#   'id': 2054538028,
#   'node_id': 'PR_kwDOIPDwls56dcMs',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26075',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/26075.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/26075.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075',
#   'number': 26075,
#   'state': 'open',
#   'locked': False,
#   'title': 'huggingface: fix _convert_TGI_message_to_LC_message issue, which will replace all …',
#   'user': {'login': 'sywangyi',
#    'id': 36058628,
#    'node_id': 'MDQ6VXNlcjM2MDU4NjI4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36058628?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sywangyi',
#    'html_url': 'https://github.com/sywangyi',
#    'followers_url': 'https://api.github.com/users/sywangyi/followers',
#    'following_url': 'https://api.github.com/users/sywangyi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sywangyi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sywangyi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sywangyi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sywangyi/orgs',
#    'repos_url': 'https://api.github.com/users/sywangyi/repos',
#    'events_url': 'https://api.github.com/users/sywangyi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sywangyi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '…\' in content like It\'s to It"s and cause json parser fail\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n    - **Twitter handle:** if your PR gets announced, and you\'d like a mention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'created_at': '2024-09-05T00:48:35Z',
#   'updated_at': '2024-09-05T00:51:01Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'c6b19b9d24b5d8723add534d722f88794ec12e03',
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/47670fd0f1c33f9c843b8e838cd1f2361df6b70f',
#   'head': {'label': 'sywangyi:tgi_huggingface_fix',
#    'ref': 'tgi_huggingface_fix',
#    'sha': '47670fd0f1c33f9c843b8e838cd1f2361df6b70f',
#    'user': {'login': 'sywangyi',
#     'id': 36058628,
#     'node_id': 'MDQ6VXNlcjM2MDU4NjI4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36058628?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sywangyi',
#     'html_url': 'https://github.com/sywangyi',
#     'followers_url': 'https://api.github.com/users/sywangyi/followers',
#     'following_url': 'https://api.github.com/users/sywangyi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sywangyi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sywangyi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sywangyi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sywangyi/orgs',
#     'repos_url': 'https://api.github.com/users/sywangyi/repos',
#     'events_url': 'https://api.github.com/users/sywangyi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sywangyi/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 852205675,
#     'node_id': 'R_kgDOMsugaw',
#     'name': 'langchain',
#     'full_name': 'sywangyi/langchain',
#     'private': False,
#     'owner': {'login': 'sywangyi',
#      'id': 36058628,
#      'node_id': 'MDQ6VXNlcjM2MDU4NjI4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/36058628?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sywangyi',
#      'html_url': 'https://github.com/sywangyi',
#      'followers_url': 'https://api.github.com/users/sywangyi/followers',
#      'following_url': 'https://api.github.com/users/sywangyi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sywangyi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sywangyi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sywangyi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sywangyi/orgs',
#      'repos_url': 'https://api.github.com/users/sywangyi/repos',
#      'events_url': 'https://api.github.com/users/sywangyi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sywangyi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/sywangyi/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/sywangyi/langchain',
#     'forks_url': 'https://api.github.com/repos/sywangyi/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/sywangyi/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/sywangyi/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/sywangyi/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/sywangyi/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/sywangyi/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/sywangyi/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/sywangyi/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/sywangyi/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/sywangyi/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/sywangyi/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/sywangyi/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/sywangyi/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/sywangyi/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/sywangyi/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/sywangyi/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/sywangyi/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/sywangyi/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/sywangyi/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/sywangyi/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/sywangyi/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/sywangyi/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/sywangyi/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/sywangyi/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/sywangyi/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/sywangyi/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/sywangyi/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/sywangyi/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/sywangyi/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/sywangyi/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/sywangyi/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/sywangyi/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/sywangyi/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/sywangyi/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/sywangyi/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/sywangyi/langchain/deployments',
#     'created_at': '2024-09-04T12:12:08Z',
#     'updated_at': '2024-09-05T00:44:44Z',
#     'pushed_at': '2024-09-05T00:46:19Z',
#     'git_url': 'git://github.com/sywangyi/langchain.git',
#     'ssh_url': 'git@github.com:sywangyi/langchain.git',
#     'clone_url': 'https://github.com/sywangyi/langchain.git',
#     'svn_url': 'https://github.com/sywangyi/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 237811,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'de97d5064437c98f34dae0b0afa3b61162790726',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-09-05T11:01:07Z',
#     'pushed_at': '2024-09-05T04:23:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 293227,
#     'stargazers_count': 91964,
#     'watchers_count': 91964,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14627,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 801,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14627,
#     'open_issues': 801,
#     'watchers': 91964,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/26075'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/26075/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26075/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/47670fd0f1c33f9c843b8e838cd1f2361df6b70f'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26074',
#   'id': 2054527654,
#   'node_id': 'PR_kwDOIPDwls56dZqm',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/26074',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/26074.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/26074.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074',
#   'number': 26074,
#   'state': 'open',
#   'locked': False,
#   'title': "Update FeatureTables.js to reflect Cohere's support for JSON mode",
#   'user': {'login': 'ryanchase-0to1',
#    'id': 167824500,
#    'node_id': 'U_kgDOCgDMdA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167824500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryanchase-0to1',
#    'html_url': 'https://github.com/ryanchase-0to1',
#    'followers_url': 'https://api.github.com/users/ryanchase-0to1/followers',
#    'following_url': 'https://api.github.com/users/ryanchase-0to1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ryanchase-0to1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ryanchase-0to1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ryanchase-0to1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ryanchase-0to1/orgs',
#    'repos_url': 'https://api.github.com/users/ryanchase-0to1/repos',
#    'events_url': 'https://api.github.com/users/ryanchase-0to1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ryanchase-0to1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '- [ ] **PR title**: "docs: update FeatureTables.js to reflect Cohere\'s support for JSON mode"\r\n- [ ] **PR message**: Update FeatureTables.js to reflect Cohere\'s support for JSON mode\r\n\r\n- [ ] **Description:** updated Cohere\'s record in the Featured Providers table [1].  Set "json_mode" to true as Cohere\'s models support JSON mode [2].\r\n\r\n[1] source table: https://python.langchain.com/v0.2/docs/integrations/chat/#featured-providers\r\n\r\n[2] Cohere\'s api reference showing support for JSON mode  i.e. response_format={ "type": "json_object" }\r\nhttps://docs.cohere.com/docs/structured-outputs-json\r\n\r\n- **Twitter handle:** @ryanchase1',
#   'created_at': '2024-09-05T00:35:39Z',
#   'updated_at': '2024-09-05T00:48:26Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '5de6bf5af393711decf9a9c0ff1d2c3ad5d76b32',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26074/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/26074/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/26074/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/9aaac9ef5ec884dbab86f882b25a4c0d778a28df',
#   'head': {'label': 'ryanchase-0to1:master',
#    'ref': 'master',
#    'sha': '9aaac9ef5ec884dbab86f882b25a4c0d778a28df',
#    'user': {'login': 'ryanchase-0to1',
#     'id': 167824500,
#     'node_id': 'U_kgDOCgDMdA',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/167824500?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ryanchase-0to1',
#     'html_url': 'https://github.com/ryanchase-0to1',
#     'followers_url': 'https://api.github.com/users/ryanchase-0to1/followers',
# ...
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 6232714130,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rkg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XL',
#     'name': 'size:XL',
#     'color': 'E99695',
#     'default': False,
#     'description': 'This PR changes 500-999 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25948/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25948/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25948/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/7f00ba8e2d8e0f9282596c2dd318f94b00386c37',
#   'head': {'label': 'rishh76:intergration_monsterapi',
#    'ref': 'intergration_monsterapi',
#    'sha': '7f00ba8e2d8e0f9282596c2dd318f94b00386c37',
#    'user': {'login': 'rishh76',
#     'id': 171783306,
#     'node_id': 'U_kgDOCj00ig',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/171783306?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/rishh76',
#     'html_url': 'https://github.com/rishh76',
#     'followers_url': 'https://api.github.com/users/rishh76/followers',
#     'following_url': 'https://api.github.com/users/rishh76/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/rishh76/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/rishh76/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/rishh76/subscriptions',
#     'organizations_url': 'https://api.github.com/users/rishh76/orgs',
#     'repos_url': 'https://api.github.com/users/rishh76/repos',
#     'events_url': 'https://api.github.com/users/rishh76/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/rishh76/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 822449730,
#     'node_id': 'R_kgDOMQWWQg',
#     'name': 'langchain',
#     'full_name': 'rishh76/langchain',
#     'private': False,
#     'owner': {'login': 'rishh76',
#      'id': 171783306,
#      'node_id': 'U_kgDOCj00ig',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/171783306?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rishh76',
#      'html_url': 'https://github.com/rishh76',
#      'followers_url': 'https://api.github.com/users/rishh76/followers',
#      'following_url': 'https://api.github.com/users/rishh76/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rishh76/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rishh76/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rishh76/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rishh76/orgs',
#      'repos_url': 'https://api.github.com/users/rishh76/repos',
#      'events_url': 'https://api.github.com/users/rishh76/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rishh76/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/rishh76/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/rishh76/langchain',
#     'forks_url': 'https://api.github.com/repos/rishh76/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/rishh76/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/rishh76/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/rishh76/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/rishh76/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/rishh76/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/rishh76/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/rishh76/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/rishh76/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/rishh76/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/rishh76/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/rishh76/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/rishh76/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/rishh76/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/rishh76/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/rishh76/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/rishh76/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/rishh76/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/rishh76/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/rishh76/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/rishh76/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/rishh76/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/rishh76/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/rishh76/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/rishh76/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/rishh76/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/rishh76/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/rishh76/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/rishh76/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/rishh76/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/rishh76/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/rishh76/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/rishh76/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/rishh76/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/rishh76/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/rishh76/langchain/deployments',
#     'created_at': '2024-07-01T07:15:19Z',
#     'updated_at': '2024-07-01T07:15:19Z',
#     'pushed_at': '2024-09-03T05:17:26Z',
#     'git_url': 'git://github.com/rishh76/langchain.git',
#     'ssh_url': 'git@github.com:rishh76/langchain.git',
#     'clone_url': 'https://github.com/rishh76/langchain.git',
#     'svn_url': 'https://github.com/rishh76/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 205851,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'ef329f681915ee696a5ddbe0cf9bf87a4406cdec',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-09-05T11:01:07Z',
#     'pushed_at': '2024-09-05T04:23:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 293227,
#     'stargazers_count': 91964,
#     'watchers_count': 91964,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14627,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 801,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14627,
#     'open_issues': 801,
#     'watchers': 91964,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25948'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25948'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25948'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25948/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25948/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25948/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/7f00ba8e2d8e0f9282596c2dd318f94b00386c37'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': 'de97d5064437c98f34dae0b0afa3b61162790726',
#   'node_id': 'C_kwDOIPDwltoAKGRlOTdkNTA2NDQzN2M5OGYzNGRhZTBiMGFmYTNiNjExNjI3OTA3MjY',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-09-04T18:58:36Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-04T18:58:36Z'},
#    'message': 'core,standard-tests[patch]: add Ser/Des test and update serialization mapping (#26042)',
#    'tree': {'sha': 'f7da93b67685eb33bb6cd597869efebe1cb1a030',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/f7da93b67685eb33bb6cd597869efebe1cb1a030'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/de97d5064437c98f34dae0b0afa3b61162790726',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nCWte3AJ7RyuVIMKzpsQL\n=Cl7Q\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree f7da93b67685eb33bb6cd597869efebe1cb1a030\nparent af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886\nparent 1241a004cbcddd7794f1a6ba064e8a0ca06e1065\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1725476316 -0700\ncommitter GitHub <noreply@github.com> 1725476316 -0700\n\ncore,standard-tests[patch]: add Ser/Des test and update serialization mapping (#26042)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/de97d5064437c98f34dae0b0afa3b61162790726',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/de97d5064437c98f34dae0b0afa3b61162790726',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/de97d5064437c98f34dae0b0afa3b61162790726/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886'},
#    {'sha': '1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/1241a004cbcddd7794f1a6ba064e8a0ca06e1065'}]},
#  {'sha': '1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#   'node_id': 'C_kwDOIPDwltoAKDEyNDFhMDA0Y2JjZGRkNzc5NGYxYTZiYTA2NGU4YTBjYTA2ZTEwNjU',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:44:59Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:44:59Z'},
#    'message': 'fmt',
#    'tree': {'sha': 'f7da93b67685eb33bb6cd597869efebe1cb1a030',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/f7da93b67685eb33bb6cd597869efebe1cb1a030'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/1241a004cbcddd7794f1a6ba064e8a0ca06e1065',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/1241a004cbcddd7794f1a6ba064e8a0ca06e1065/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/4ba14ae9e5545c3905aded58c0435f10b77f6b02'}]},
#  {'sha': '4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#   'node_id': 'C_kwDOIPDwltoAKDRiYTE0YWU5ZTU1NDVjMzkwNWFkZWQ1OGMwNDM1ZjEwYjc3ZjZiMDI',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:34:59Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:34:59Z'},
#    'message': 'fmt',
#    'tree': {'sha': '45d2041823d12336ea1715eb25d4bacf3213eaf9',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/45d2041823d12336ea1715eb25d4bacf3213eaf9'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/4ba14ae9e5545c3905aded58c0435f10b77f6b02',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4ba14ae9e5545c3905aded58c0435f10b77f6b02/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe'}]},
#  {'sha': 'dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#   'node_id': 'C_kwDOIPDwltoAKGRiYTMwODQ0N2QwZTE4NTc4ZmJjYmYzYWRmYmJlYjVkODc4OWM3ZmU',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:28:04Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:28:04Z'},
#    'message': 'fmt',
#    'tree': {'sha': 'f5b6b2037e0e850d9f3c4f3a386c819bf916c4c3',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/f5b6b2037e0e850d9f3c4f3a386c819bf916c4c3'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/dba308447d0e18578fbcbf3adfbbeb5d8789c7fe/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'fdf6fbde186b231a9fc0e5bfde163db882864316',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fdf6fbde186b231a9fc0e5bfde163db882864316',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/fdf6fbde186b231a9fc0e5bfde163db882864316'}]},
#  {'sha': 'fdf6fbde186b231a9fc0e5bfde163db882864316',
#   'node_id': 'C_kwDOIPDwltoAKGZkZjZmYmRlMTg2YjIzMWE5ZmMwZTViZmRlMTYzZGI4ODI4NjQzMTY',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:12:11Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:12:11Z'},
#    'message': 'fmt',
#    'tree': {'sha': '24918d810bd85e16b7b6ece544aca16912dac015',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/24918d810bd85e16b7b6ece544aca16912dac015'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/fdf6fbde186b231a9fc0e5bfde163db882864316',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fdf6fbde186b231a9fc0e5bfde163db882864316',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/fdf6fbde186b231a9fc0e5bfde163db882864316',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fdf6fbde186b231a9fc0e5bfde163db882864316/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '576574c82c21ce3019c05f627b6bf08333d255b2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/576574c82c21ce3019c05f627b6bf08333d255b2',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/576574c82c21ce3019c05f627b6bf08333d255b2'}]},
#  {'sha': '576574c82c21ce3019c05f627b6bf08333d255b2',
#   'node_id': 'C_kwDOIPDwltoAKDU3NjU3NGM4MmMyMWNlMzAxOWMwNWY2MjdiNmJmMDgzMzNkMjU1YjI',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:05:36Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T18:05:36Z'},
#    'message': 'fmt',
#    'tree': {'sha': '306ada35ec44d7eefde3c0be82c7d39ba35d29c4',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/306ada35ec44d7eefde3c0be82c7d39ba35d29c4'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/576574c82c21ce3019c05f627b6bf08333d255b2',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/576574c82c21ce3019c05f627b6bf08333d255b2',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/576574c82c21ce3019c05f627b6bf08333d255b2',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/576574c82c21ce3019c05f627b6bf08333d255b2/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '7bf54636ff75a8c1bc9899abc084927b36745126',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7bf54636ff75a8c1bc9899abc084927b36745126',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/7bf54636ff75a8c1bc9899abc084927b36745126'}]},
#  {'sha': '7bf54636ff75a8c1bc9899abc084927b36745126',
#   'node_id': 'C_kwDOIPDwltoAKDdiZjU0NjM2ZmY3NWE4YzFiYzk4OTlhYmMwODQ5MjdiMzY3NDUxMjY',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T17:24:42Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T17:24:42Z'},
#    'message': 'make',
#    'tree': {'sha': '2c6ed401a7afcdda7ffe77f463eb212763c7a39b',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/2c6ed401a7afcdda7ffe77f463eb212763c7a39b'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/7bf54636ff75a8c1bc9899abc084927b36745126',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7bf54636ff75a8c1bc9899abc084927b36745126',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/7bf54636ff75a8c1bc9899abc084927b36745126',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7bf54636ff75a8c1bc9899abc084927b36745126/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3ec93c2817a03eeb178602d05f84bb41bd49bff5'}]},
#  {'sha': '3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#   'node_id': 'C_kwDOIPDwltoAKDNlYzkzYzI4MTdhMDNlZWIxNzg2MDJkMDVmODRiYjQxYmQ0OWJmZjU',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T17:24:06Z'},
#    'committer': {'name': 'Bagatur',
#     'email': 'baskaryan@gmail.com',
#     'date': '2024-09-04T17:24:06Z'},
#    'message': 'standard-tests[patch]: add Ser/Des test',
#    'tree': {'sha': '9fd11b95f7a64f93390ba806ee54b02c7c12e7d9',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/9fd11b95f7a64f93390ba806ee54b02c7c12e7d9'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3ec93c2817a03eeb178602d05f84bb41bd49bff5',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3ec93c2817a03eeb178602d05f84bb41bd49bff5/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886'}]},
#  {'sha': 'af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#   'node_id': 'C_kwDOIPDwltoAKGFmMTFmYmZiZjZhZTNmYWU5YTJmZDBjZjZlNTFiNGU4ZjM4YzQ4ODY',
#   'commit': {'author': {'name': 'Friso H. Kingma',
#     'email': 'fhkingma@gmail.com',
#     'date': '2024-09-04T13:26:48Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-04T13:26:48Z'},
#    'message': 'langchain_openai: Make sure the response from the async client in the astream method of ChatOpenAI is properly awaited in case of "include_response_headers=True" (#26031)\n\n- **Description:** This is a **one line change**. the\r\n`self.async_client.with_raw_response.create(**payload)` call is not\r\nproperly awaited within the `_astream` method. In `_agenerate` this is\r\ndone already, but likely forgotten in the other method.\r\n  - **Issue:** Not applicable\r\n  - **Dependencies:** No dependencies required.\r\n\r\n(If no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.)\r\n\r\n---------\r\n\r\nCo-authored-by: Chester Curme <chester.curme@gmail.com>',
#    'tree': {'sha': 'eed91be314bcb276914c0f33bb4b1dd370a37031',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/eed91be314bcb276914c0f33bb4b1dd370a37031'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nEBeXsDnSXWaWvMG/9MAF\n=FxJB\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree eed91be314bcb276914c0f33bb4b1dd370a37031\nparent c8122372177305c964866691a8254cb99c3809d2\nauthor Friso H. Kingma <fhkingma@gmail.com> 1725456408 +0200\ncommitter GitHub <noreply@github.com> 1725456408 +0000\n\nlangchain_openai: Make sure the response from the async client in the astream method of ChatOpenAI is properly awaited in case of "include_response_headers=True" (#26031)\n\n- **Description:** This is a **one line change**. the\r\n`self.async_client.with_raw_response.create(**payload)` call is not\r\nproperly awaited within the `_astream` method. In `_agenerate` this is\r\ndone already, but likely forgotten in the other method.\r\n  - **Issue:** Not applicable\r\n  - **Dependencies:** No dependencies required.\r\n\r\n(If no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.)\r\n\r\n---------\r\n\r\nCo-authored-by: Chester Curme <chester.curme@gmail.com>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/af11fbfbf6ae3fae9a2fd0cf6e51b4e8f38c4886/comments',
#   'author': {'login': 'fhkingma',
#    'id': 7791825,
#    'node_id': 'MDQ6VXNlcjc3OTE4MjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7791825?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fhkingma',
#    'html_url': 'https://github.com/fhkingma',
#    'followers_url': 'https://api.github.com/users/fhkingma/followers',
#    'following_url': 'https://api.github.com/users/fhkingma/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fhkingma/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fhkingma/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fhkingma/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fhkingma/orgs',
#    'repos_url': 'https://api.github.com/users/fhkingma/repos',
#    'events_url': 'https://api.github.com/users/fhkingma/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fhkingma/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c8122372177305c964866691a8254cb99c3809d2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8122372177305c964866691a8254cb99c3809d2',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c8122372177305c964866691a8254cb99c3809d2'}]},
#  {'sha': 'c8122372177305c964866691a8254cb99c3809d2',
#   'node_id': 'C_kwDOIPDwltoAKGM4MTIyMzcyMTc3MzA1Yzk2NDg2NjY5MWE4MjU0Y2I5OWMzODA5ZDI',
#   'commit': {'author': {'name': 'ZhangShenao',
#     'email': '15201440436@163.com',
#     'date': '2024-09-04T13:26:26Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-04T13:26:26Z'},
#    'message': 'Improvement[Community] Improve args description in api doc of `DocArrayInMemorySearch` (#26024)\n\n- Add missing arg\r\n- Remove redundant arg',
#    'tree': {'sha': '5f3491b18afdca201c902ba7ed0dfb9a56d02681',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/5f3491b18afdca201c902ba7ed0dfb9a56d02681'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c8122372177305c964866691a8254cb99c3809d2',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nPRw/uBZN60QXeVludAUn\n=SitP\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 5f3491b18afdca201c902ba7ed0dfb9a56d02681\nparent c649b449d71efdde03a6d9b74e04029d62858c9f\nauthor ZhangShenao <15201440436@163.com> 1725456386 +0800\ncommitter GitHub <noreply@github.com> 1725456386 -0400\n\nImprovement[Community] Improve args description in api doc of `DocArrayInMemorySearch` (#26024)\n\n- Add missing arg\r\n- Remove redundant arg'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8122372177305c964866691a8254cb99c3809d2',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c8122372177305c964866691a8254cb99c3809d2',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8122372177305c964866691a8254cb99c3809d2/comments',
#   'author': {'login': 'ZhangShenao',
#    'id': 24444502,
#    'node_id': 'MDQ6VXNlcjI0NDQ0NTAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24444502?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZhangShenao',
#    'html_url': 'https://github.com/ZhangShenao',
#    'followers_url': 'https://api.github.com/users/ZhangShenao/followers',
#    'following_url': 'https://api.github.com/users/ZhangShenao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ZhangShenao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ZhangShenao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ZhangShenao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ZhangShenao/orgs',
#    'repos_url': 'https://api.github.com/users/ZhangShenao/repos',
#    'events_url': 'https://api.github.com/users/ZhangShenao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ZhangShenao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c649b449d71efdde03a6d9b74e04029d62858c9f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c649b449d71efdde03a6d9b74e04029d62858c9f',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c649b449d71efdde03a6d9b74e04029d62858c9f'}]},
#  {'sha': 'c649b449d71efdde03a6d9b74e04029d62858c9f',
#   'node_id': 'C_kwDOIPDwltoAKGM2NDliNDQ5ZDcxZWZkZGUwM2E2ZDliNzRlMDQwMjlkNjI4NThjOWY',
#   'commit': {'author': {'name': 'Tomaz Bratanic',
#     'email': 'bratanic.tomaz@gmail.com',
#     'date': '2024-09-04T13:15:43Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-04T13:15:43Z'},
#    'message': "Add the option to ignore structured output method to LLM graph transf… (#26013)\n\nOpen source models like Llama3.1 have function calling, but it's not\r\nthat great. Therefore, we introduce the option to ignore model's\r\nfunction calling and just use the prompt-based approach",
#    'tree': {'sha': '811393664012d8ca1d4e69b31e41804b4b984c02',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/811393664012d8ca1d4e69b31e41804b4b984c02'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c649b449d71efdde03a6d9b74e04029d62858c9f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nNO90Es16UTlV7HVZoKIY\n=V4mD\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 811393664012d8ca1d4e69b31e41804b4b984c02\nparent 34fc00aff17d1913a1cfe4b205e732982f98f7b8\nauthor Tomaz Bratanic <bratanic.tomaz@gmail.com> 1725455743 +0900\ncommitter GitHub <noreply@github.com> 1725455743 -0400\n\nAdd the option to ignore structured output method to LLM graph transf… (#26013)\n\nOpen source models like Llama3.1 have function calling, but it's not\r\nthat great. Therefore, we introduce the option to ignore model's\r\nfunction calling and just use the prompt-based approach"}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c649b449d71efdde03a6d9b74e04029d62858c9f',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c649b449d71efdde03a6d9b74e04029d62858c9f',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c649b449d71efdde03a6d9b74e04029d62858c9f/comments',
#   'author': {'login': 'tomasonjo',
#    'id': 19948365,
#    'node_id': 'MDQ6VXNlcjE5OTQ4MzY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19948365?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tomasonjo',
#    'html_url': 'https://github.com/tomasonjo',
#    'followers_url': 'https://api.github.com/users/tomasonjo/followers',
#    'following_url': 'https://api.github.com/users/tomasonjo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tomasonjo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tomasonjo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tomasonjo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tomasonjo/orgs',
#    'repos_url': 'https://api.github.com/users/tomasonjo/repos',
#    'events_url': 'https://api.github.com/users/tomasonjo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tomasonjo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/34fc00aff17d1913a1cfe4b205e732982f98f7b8'}]},
#  {'sha': '34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#   'node_id': 'C_kwDOIPDwltoAKDM0ZmMwMGFmZjE3ZDE5MTNhMWNmZTRiMjA1ZTczMjk4MmY5OGY3Yjg',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-09-04T00:27:10Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-04T00:27:10Z'},
#    'message': 'openai[patch]: add back azure embeddings api_version alias (#26003)',
#    'tree': {'sha': '9c471c7be593c9aa94097e08eeeae9200c0ce056',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/9c471c7be593c9aa94097e08eeeae9200c0ce056'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nnOtRqSHjz/sCbig87zD+\n=SD4c\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 9c471c7be593c9aa94097e08eeeae9200c0ce056\nparent bc3b851f08ee58bba2a6ff2600a26d1e9c964f42\nparent 4b99426a4f8d738c59ce782ecf9eb3fac8fc3c0b\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1725409630 -0700\ncommitter GitHub <noreply@github.com> 1725409630 -0700\n\nopenai[patch]: add back azure embeddings api_version alias (#26003)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/34fc00aff17d1913a1cfe4b205e732982f98f7b8',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/34fc00aff17d1913a1cfe4b205e732982f98f7b8/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
# ...
#    'subscriptions_url': 'https://api.github.com/users/maxschulz-COL/subscriptions',
#    'organizations_url': 'https://api.github.com/users/maxschulz-COL/orgs',
#    'repos_url': 'https://api.github.com/users/maxschulz-COL/repos',
#    'events_url': 'https://api.github.com/users/maxschulz-COL/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/maxschulz-COL/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34'}]},
#  {'sha': 'c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#   'node_id': 'C_kwDOIPDwltoAKGM3MTU0YTQwNDU3YjE2YjExZmRmNmMwYjJmN2Y4YzMzMjNiNjJkMzQ',
#   'commit': {'author': {'name': 'Jorge Piedrahita Ortiz',
#     'email': 'jhpiedrahitao97@gmail.com',
#     'date': '2024-09-03T14:18:15Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-03T14:18:15Z'},
#    'message': 'community: sambastudio llms api v2 support (#25063)\n\n- **Description:** SambaStudio GenericV2 API support',
#    'tree': {'sha': 'c692bcefd7917da65c3f8bf7ba03722b1a7860d4',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c692bcefd7917da65c3f8bf7ba03722b1a7860d4'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nW5K0Fo9ThkF3cVjsWMn5\n=9niS\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c692bcefd7917da65c3f8bf7ba03722b1a7860d4\nparent 8d784db107fc3d7728c9966087d0fe5d120c6291\nauthor Jorge Piedrahita Ortiz <jhpiedrahitao97@gmail.com> 1725373095 -0500\ncommitter GitHub <noreply@github.com> 1725373095 -0400\n\ncommunity: sambastudio llms api v2 support (#25063)\n\n- **Description:** SambaStudio GenericV2 API support'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7154a40457b16b11fdf6c0b2f7f8c3323b62d34/comments',
#   'author': {'login': 'jhpiedrahitao',
#    'id': 14959173,
#    'node_id': 'MDQ6VXNlcjE0OTU5MTcz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14959173?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jhpiedrahitao',
#    'html_url': 'https://github.com/jhpiedrahitao',
#    'followers_url': 'https://api.github.com/users/jhpiedrahitao/followers',
#    'following_url': 'https://api.github.com/users/jhpiedrahitao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jhpiedrahitao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jhpiedrahitao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jhpiedrahitao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jhpiedrahitao/orgs',
#    'repos_url': 'https://api.github.com/users/jhpiedrahitao/repos',
#    'events_url': 'https://api.github.com/users/jhpiedrahitao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jhpiedrahitao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8d784db107fc3d7728c9966087d0fe5d120c6291',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d784db107fc3d7728c9966087d0fe5d120c6291',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/8d784db107fc3d7728c9966087d0fe5d120c6291'}]},
#  {'sha': '8d784db107fc3d7728c9966087d0fe5d120c6291',
#   'node_id': 'C_kwDOIPDwltoAKDhkNzg0ZGIxMDdmYzNkNzcyOGM5OTY2MDg3ZDBmZTVkMTIwYzYyOTE',
#   'commit': {'author': {'name': 'ZhangShenao',
#     'email': '15201440436@163.com',
#     'date': '2024-09-03T08:24:23Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-03T08:24:23Z'},
#    'message': 'docs: Add missing args in api doc of `WebResearchRetriever` (#25949)\n\nAdd missing args in api doc of `WebResearchRetriever`',
#    'tree': {'sha': '5cdfa625ea8c0f12137aa6e06f7d2122877f5fe0',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/5cdfa625ea8c0f12137aa6e06f7d2122877f5fe0'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/8d784db107fc3d7728c9966087d0fe5d120c6291',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nQhJvdD8vLHwgBtdciXoY\n=/dsw\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 5cdfa625ea8c0f12137aa6e06f7d2122877f5fe0\nparent da113f63630f4c37ba9271e8580da5b77cbecc83\nauthor ZhangShenao <15201440436@163.com> 1725351863 +0800\ncommitter GitHub <noreply@github.com> 1725351863 -0700\n\ndocs: Add missing args in api doc of `WebResearchRetriever` (#25949)\n\nAdd missing args in api doc of `WebResearchRetriever`'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d784db107fc3d7728c9966087d0fe5d120c6291',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/8d784db107fc3d7728c9966087d0fe5d120c6291',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d784db107fc3d7728c9966087d0fe5d120c6291/comments',
#   'author': {'login': 'ZhangShenao',
#    'id': 24444502,
#    'node_id': 'MDQ6VXNlcjI0NDQ0NTAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24444502?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZhangShenao',
#    'html_url': 'https://github.com/ZhangShenao',
#    'followers_url': 'https://api.github.com/users/ZhangShenao/followers',
#    'following_url': 'https://api.github.com/users/ZhangShenao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ZhangShenao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ZhangShenao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ZhangShenao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ZhangShenao/orgs',
#    'repos_url': 'https://api.github.com/users/ZhangShenao/repos',
#    'events_url': 'https://api.github.com/users/ZhangShenao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ZhangShenao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'da113f63630f4c37ba9271e8580da5b77cbecc83',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/da113f63630f4c37ba9271e8580da5b77cbecc83',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/da113f63630f4c37ba9271e8580da5b77cbecc83'}]},
#  {'sha': 'da113f63630f4c37ba9271e8580da5b77cbecc83',
#   'node_id': 'C_kwDOIPDwltoAKGRhMTEzZjYzNjMwZjRjMzdiYTkyNzFlODU4MGRhNWI3N2NiZWNjODM',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-09-03T08:20:58Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-09-03T08:20:58Z'},
#    'message': 'docs: ChatOpenAI.with_structured_output nits (#25952)',
#    'tree': {'sha': '21d4aaa799196b334e05a6eef3f3f4679e966c74',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/21d4aaa799196b334e05a6eef3f3f4679e966c74'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/da113f63630f4c37ba9271e8580da5b77cbecc83',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\niZERq7RmxbvvtoE1A1BU\n=3aSj\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 21d4aaa799196b334e05a6eef3f3f4679e966c74\nparent 5b99bb2437a00a6ec3dfea0ba2652bbd5edee71f\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1725351658 -0700\ncommitter GitHub <noreply@github.com> 1725351658 +0000\n\ndocs: ChatOpenAI.with_structured_output nits (#25952)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/da113f63630f4c37ba9271e8580da5b77cbecc83',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/da113f63630f4c37ba9271e8580da5b77cbecc83',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/da113f63630f4c37ba9271e8580da5b77cbecc83/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '5b99bb2437a00a6ec3dfea0ba2652bbd5edee71f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/5b99bb2437a00a6ec3dfea0ba2652bbd5edee71f',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/5b99bb2437a00a6ec3dfea0ba2652bbd5edee71f'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2024-09-05.md
# 'langchain-ai_langchain_2024-09-05.md'

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25519: docs: add prompt to install nltk (关闭时间 2024-08-18T06:22:49Z)
# Issue #25518: docs: add prompt to install beautifulsoup4. (关闭时间 2024-08-18T06:23:24Z)

# %%
# 获取过去3天的日期
three_days_ago = datetime.now() - timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25519: docs: add prompt to install nltk (关闭时间 2024-08-18T06:22:49Z)
# Issue #25518: docs: add prompt to install beautifulsoup4. (关闭时间 2024-08-18T06:23:24Z)
# Issue #25508: add embeddings integration tests (关闭时间 2024-08-16T20:20:37Z)
# Issue #25507: "from langchain_anthropic import ChatAnthropic" fails (关闭时间 2024-08-16T20:37:43Z)
# Issue #25504: docs: fix Databricks Vector Search demo notebook (关闭时间 2024-08-16T20:24:30Z)
# Issue #25502: openai[patch]: update core dep (关闭时间 2024-08-16T18:30:18Z)
# Issue #25498: core[patch]: Release 0.2.33 (关闭时间 2024-08-16T18:18:54Z)
# Issue #25496: openai[patch]: Release 0.1.22 (关闭时间 2024-08-16T16:53:04Z)
# Issue #25494: docs: use .invoke rather than __call__ in openai integration notebook (关闭时间 2024-08-16T15:59:18Z)
# Issue #25488: openai[patch]: fix json mode for Azure (关闭时间 2024-08-16T16:50:51Z)
# Issue #25485: langchain_openai>=0.1.21 not compatible with AzureChatOpenAI and response_format={"type": "json_object"} (关闭时间 2024-08-16T13:24:12Z)
# Issue #25482: DOC: <Issue related to /v0.2/docs/tutorials/local_rag/> Missing a requirement (关闭时间 2024-08-18T06:23:25Z)
# Issue #25480: TypeError: Got unknown type 'ToolMessage'. (关闭时间 2024-08-18T00:48:52Z)
# Issue #25479: AzureChatOpenAI's JSON mode fails with AttributeError: 'NoneType' object has no attribute 'beta' (关闭时间 2024-08-16T19:00:12Z)
# Issue #25473: Unstructured Markdown Loader object which requires also NLTK package (关闭时间 2024-08-18T06:22:51Z)
# Issue #25471: The minimum supported Python version for this project (关闭时间 2024-08-16T04:52:56Z)
# Issue #25465: langchain-box: add langchain box package and DocumentLoader (关闭时间 2024-08-16T19:21:08Z)
# Issue #25463: docs: fix mimetype parser docstring (关闭时间 2024-08-15T23:16:53Z)
# Issue #25461: Langchain Agent with Pydantic tools running in Linux Environment  (关闭时间 2024-08-16T02:03:47Z)
# Issue #25458: langchain-box: Add DocumentLoader (关闭时间 2024-08-16T00:53:46Z)
# Issue #25457: core[minor], anthropic[patch]: Upgrade @root_validator usage to be consistent with pydantic 2 (关闭时间 2024-08-15T20:09:35Z)
# Issue #25455: voyageai[patch]: Upgrade root validators for pydantic 2 (关闭时间 2024-08-15T19:30:41Z)
# Issue #25454: ai21[patch]: Upgrade @root_validators for pydantic 2 migration (关闭时间 2024-08-15T18:54:09Z)
# Issue #25453: pinecone[patch]: Upgrade @root_validators to be consistent with pydantic 2 (关闭时间 2024-08-15T19:45:15Z)
# Issue #25450: docs: `arxiv` page update (关闭时间 2024-08-15T18:30:36Z)
# Issue #25448: docs: format oai embeddings docstring (关闭时间 2024-08-15T16:57:55Z)
# Issue #25447: docs: fix api ref mod links in pkg page (关闭时间 2024-08-15T16:52:12Z)
# Issue #25446: mistralai[patch]: Update more @root_validators for pydantic 2 compatibility (关闭时间 2024-08-15T16:44:42Z)
# Issue #25444: docs[patch]: Update code that checks API keys (关闭时间 2024-08-15T16:52:37Z)
# Issue #25443: fireworks[patch]: Upgrade @root_validators to be pydantic 2 compliant  (关闭时间 2024-08-15T16:56:48Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2024-08-18T14:13:15.171549+0000 INFO Exported time-range progress to daily_progress/langchain-ai_langchain/2024-08-15_to_2024-08-18.md
# 'daily_progress/langchain-ai_langchain/2024-08-15_to_2024-08-18.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2024-08-18T14:13:17.054441+0000 INFO Exported daily progress to daily_progress/langchain-ai_langchain/2024-08-18.md
# 'daily_progress/langchain-ai_langchain/2024-08-18.md'

# %% [markdown]
# ### Homework: [可选] 尝试扩展 GitHubClient，使其支持 Since + Until 参数的特定时间段筛选
# ![image.png](attachment:12c41fc1-1001-4b5c-9905-131457956a2e.png)![image.png](attachment:532f2f6e-17e4-4d49-934e-d7301d9e8d9b.png)![image.png](attachment:d7c01738-e689-409e-b9aa-476cad3f8220.png)![image.png](attachment:bd00a348-af22-4a69-b64d-5f676f9ed7ee.png)
